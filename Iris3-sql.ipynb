# %%
import psycopg2

# Establish a connection to the database.
# Replace parameter values with database credentials.
conn = psycopg2.connect(database="postgres", 
                        user="postgres",
                        host="localhost",
                        password="kaced14",
                        port="5432") 

# Create a cursor. The cursor allows you to execute database queries. 
cur = conn.cursor()

# Create a table. Initialise the table name, the column names and data type. 
cur.execute("""CREATE TABLE VEGT (
                    id          INT ,
                    fruit_name  TEXT,
                    vegt_name  TEXT,
                    color       TEXT,
                    price       REAL )""")
            
conn.commit()
conn.close()

# %%
import psycopg2
try:
    conn = psycopg2.connect(
          user = "postgres",
          password = "kaced14",
          host = "localhost",
          port = "5432",
          database = "postgres"
    )
    cur = conn.cursor()
    # Afficher la version de PostgreSQL 
    cur.execute("SELECT version();")
    version = cur.fetchone()
    print("Version : ", version,"\n")
  
    #fermeture de la connexion à la base de données
    cur.close()
    conn.close()
    print("La connexion PostgreSQL est fermée")
except (Exception, psycopg2.Error) as error :
    print ("Erreur lors de la connexion à PostgreSQL", error)
# Out:
# Version :  ('PostgreSQL 10.14, compiled by Visual C++ build 1800, 32-bit',)
#
# La connexion PostgreSQL est fermée

# %%
import psycopg2

# Update connection string information 
host = "<localhost>"
dbname = "<database-name>"
user = "<admin-username>"
password = "<admin-password>"
sslmode = "prefer"

# Construct connection string
conn_string = "host={0} user={1} dbname={2} password={3} sslmode={4}".format(host, user, dbname, password, sslmode)
conn = psycopg2.connect(conn_string) 
print("Connection established")

cursor = conn.cursor()

# Drop previous table of same name if one exists
cursor.execute("DROP TABLE IF EXISTS inventory;")
print("Finished dropping table (if existed)")

# Create a table
cursor.execute("CREATE TABLE inventory (id serial PRIMARY KEY, name VARCHAR(50), quantity INTEGER);")
print("Finished creating table")

# Insert some data into the table
cursor.execute("INSERT INTO inventory (name, quantity) VALUES (%s, %s);", ("banana", 150))
cursor.execute("INSERT INTO inventory (name, quantity) VALUES (%s, %s);", ("orange", 154))
cursor.execute("INSERT INTO inventory (name, quantity) VALUES (%s, %s);", ("apple", 100))
print("Inserted 3 rows of data")

# Clean up
conn.commit()
cursor.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-19-df324839bbd9> in <module>
#      10 # Construct connection string
#      11 conn_string = "host={0} user={1} dbname={2} password={3} sslmode={4}".format(host, user, dbname, password, sslmode)
# ---> 12 conn = psycopg2.connect(conn_string)
#      13 print("Connection established")
#      14
#
# ~\Anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: could not translate host name "<localhost>" to address: Unknown host

# %%
# THIS FILE WAS AUTOMATICALLY GENERATED BY deprecated_modules.py
import sys
# mypy error: Module X has no attribute y (typically for C extensions)
from . import _regression  # type: ignore
from ..externals._pep562 import Pep562
from ..utils.deprecation import _raise_dep_warning_if_not_pytest

deprecated_path = 'sklearn.neighbors.regression'
correct_import_path = 'sklearn.neighbors'

_raise_dep_warning_if_not_pytest(deprecated_path, correct_import_path)

def __getattr__(name):
    return getattr(_regression, name)

if not sys.version_info >= (3, 7):
    Pep562(__name__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-2ece97c85f43> in <module>
#       2 import sys
#       3 # mypy error: Module X has no attribute y (typically for C extensions)
# ----> 4 from . import _regression  # type: ignore
#       5 from ..externals._pep562 import Pep562
#       6 from ..utils.deprecation import _raise_dep_warning_if_not_pytest
#
# ImportError: cannot import name '_regression' from '__main__' (unknown location)

# %%
from tkinter import Tk
root = Tk() # Création de la fenêtre racine
root.mainloop() # Lancement de la boucle principale

# %%
import psycopg2
from sklearn import datasets
try:
    conn = psycopg2.connect(
          user = "postgres",
          password = "kaced14",
          host = "localhost",
          port = "5432",
          database = "postgres"
    )
    cur = conn.cursor()
    # Afficher la version de PostgreSQL 
    cur.execute("SELECT version();")
    version = cur.fetchone()
    print("Version : ", version,"\n")
    
    iris = datasets.load_iris()
    
    X= iris.data[:,:]
    Y= iris.target
    
    # Create a table
    cur.execute("CREATE TABLE Iris (sepal_length INTEGER,sepal_width INTEGER ,petal_length INTEGER, petal_width INTEGER);")
    print("Finished creating table")

    
    c=0
    for i in X:
        print(i)
        c=c+1
        # Insert some data into the table
        #cursor.execute("INSERT INTO inventory (name, quantity) VALUES (%s, %s);", ("banana", 150))
    
    print(c)
    
        
  
    #fermeture de la connexion à la base de données
    cur.close()
    conn.close()
    print("La connexion PostgreSQL est fermée")
except (Exception, psycopg2.Error) as error :
    print ("Erreur lors de la connexion à PostgreSQL", error)
# Out:
# Version :  ('PostgreSQL 10.14, compiled by Visual C++ build 1800, 32-bit',)
#
# Finished creating table
# [5.1 3.5 1.4 0.2]
# [4.9 3.  1.4 0.2]
# [4.7 3.2 1.3 0.2]
# [4.6 3.1 1.5 0.2]
# [5.  3.6 1.4 0.2]
# [5.4 3.9 1.7 0.4]
# [4.6 3.4 1.4 0.3]
# [5.  3.4 1.5 0.2]
# [4.4 2.9 1.4 0.2]
# [4.9 3.1 1.5 0.1]
# [5.4 3.7 1.5 0.2]
# [4.8 3.4 1.6 0.2]
# [4.8 3.  1.4 0.1]
# [4.3 3.  1.1 0.1]
# [5.8 4.  1.2 0.2]
# [5.7 4.4 1.5 0.4]
# [5.4 3.9 1.3 0.4]
# [5.1 3.5 1.4 0.3]
# [5.7 3.8 1.7 0.3]
# [5.1 3.8 1.5 0.3]
# [5.4 3.4 1.7 0.2]
# [5.1 3.7 1.5 0.4]
# [4.6 3.6 1.  0.2]
# [5.1 3.3 1.7 0.5]
# [4.8 3.4 1.9 0.2]
# [5.  3.  1.6 0.2]
# [5.  3.4 1.6 0.4]
# [5.2 3.5 1.5 0.2]
# [5.2 3.4 1.4 0.2]
# [4.7 3.2 1.6 0.2]
# [4.8 3.1 1.6 0.2]
# [5.4 3.4 1.5 0.4]
# [5.2 4.1 1.5 0.1]
# [5.5 4.2 1.4 0.2]
# [4.9 3.1 1.5 0.2]
# [5.  3.2 1.2 0.2]
# [5.5 3.5 1.3 0.2]
# [4.9 3.6 1.4 0.1]
# [4.4 3.  1.3 0.2]
# [5.1 3.4 1.5 0.2]
# [5.  3.5 1.3 0.3]
# [4.5 2.3 1.3 0.3]
# [4.4 3.2 1.3 0.2]
# [5.  3.5 1.6 0.6]
# [5.1 3.8 1.9 0.4]
# [4.8 3.  1.4 0.3]
# [5.1 3.8 1.6 0.2]
# [4.6 3.2 1.4 0.2]
# [5.3 3.7 1.5 0.2]
# [5.  3.3 1.4 0.2]
# [7.  3.2 4.7 1.4]
# [6.4 3.2 4.5 1.5]
# [6.9 3.1 4.9 1.5]
# [5.5 2.3 4.  1.3]
# [6.5 2.8 4.6 1.5]
# [5.7 2.8 4.5 1.3]
# [6.3 3.3 4.7 1.6]
# [4.9 2.4 3.3 1. ]
# [6.6 2.9 4.6 1.3]
# [5.2 2.7 3.9 1.4]
# [5.  2.  3.5 1. ]
# [5.9 3.  4.2 1.5]
# [6.  2.2 4.  1. ]
# [6.1 2.9 4.7 1.4]
# [5.6 2.9 3.6 1.3]
# [6.7 3.1 4.4 1.4]
# [5.6 3.  4.5 1.5]
# [5.8 2.7 4.1 1. ]
# [6.2 2.2 4.5 1.5]
# [5.6 2.5 3.9 1.1]
# [5.9 3.2 4.8 1.8]
# [6.1 2.8 4.  1.3]
# [6.3 2.5 4.9 1.5]
# [6.1 2.8 4.7 1.2]
# [6.4 2.9 4.3 1.3]
# [6.6 3.  4.4 1.4]
# [6.8 2.8 4.8 1.4]
# [6.7 3.  5.  1.7]
# [6.  2.9 4.5 1.5]
# [5.7 2.6 3.5 1. ]
# [5.5 2.4 3.8 1.1]
# [5.5 2.4 3.7 1. ]
# [5.8 2.7 3.9 1.2]
# [6.  2.7 5.1 1.6]
# [5.4 3.  4.5 1.5]
# [6.  3.4 4.5 1.6]
# [6.7 3.1 4.7 1.5]
# [6.3 2.3 4.4 1.3]
# [5.6 3.  4.1 1.3]
# [5.5 2.5 4.  1.3]
# [5.5 2.6 4.4 1.2]
# [6.1 3.  4.6 1.4]
# [5.8 2.6 4.  1.2]
# [5.  2.3 3.3 1. ]
# [5.6 2.7 4.2 1.3]
# [5.7 3.  4.2 1.2]
# [5.7 2.9 4.2 1.3]
# [6.2 2.9 4.3 1.3]
# [5.1 2.5 3.  1.1]
# [5.7 2.8 4.1 1.3]
# [6.3 3.3 6.  2.5]
# [5.8 2.7 5.1 1.9]
# [7.1 3.  5.9 2.1]
# [6.3 2.9 5.6 1.8]
# [6.5 3.  5.8 2.2]
# [7.6 3.  6.6 2.1]
# [4.9 2.5 4.5 1.7]
# [7.3 2.9 6.3 1.8]
# [6.7 2.5 5.8 1.8]
# [7.2 3.6 6.1 2.5]
# [6.5 3.2 5.1 2. ]
# [6.4 2.7 5.3 1.9]
# [6.8 3.  5.5 2.1]
# [5.7 2.5 5.  2. ]
# [5.8 2.8 5.1 2.4]
# [6.4 3.2 5.3 2.3]
# [6.5 3.  5.5 1.8]
# [7.7 3.8 6.7 2.2]
# [7.7 2.6 6.9 2.3]
# [6.  2.2 5.  1.5]
# [6.9 3.2 5.7 2.3]
# [5.6 2.8 4.9 2. ]
# [7.7 2.8 6.7 2. ]
# [6.3 2.7 4.9 1.8]
# [6.7 3.3 5.7 2.1]
# [7.2 3.2 6.  1.8]
# [6.2 2.8 4.8 1.8]
# [6.1 3.  4.9 1.8]
# [6.4 2.8 5.6 2.1]
# [7.2 3.  5.8 1.6]
# [7.4 2.8 6.1 1.9]
# [7.9 3.8 6.4 2. ]
# [6.4 2.8 5.6 2.2]
# [6.3 2.8 5.1 1.5]
# [6.1 2.6 5.6 1.4]
# [7.7 3.  6.1 2.3]
# [6.3 3.4 5.6 2.4]
# [6.4 3.1 5.5 1.8]
# [6.  3.  4.8 1.8]
# [6.9 3.1 5.4 2.1]
# [6.7 3.1 5.6 2.4]
# [6.9 3.1 5.1 2.3]
# [5.8 2.7 5.1 1.9]
# [6.8 3.2 5.9 2.3]
# [6.7 3.3 5.7 2.5]
# [6.7 3.  5.2 2.3]
# [6.3 2.5 5.  1.9]
# [6.5 3.  5.2 2. ]
# [6.2 3.4 5.4 2.3]
# [5.9 3.  5.1 1.8]
# 150
# La connexion PostgreSQL est fermée

# %%
import psycopg2
from sklearn import datasets
try:

    # Establish a connection to the database.
    # Replace parameter values with database credentials.
    conn = psycopg2.connect(database="postgres", 
                            user="postgres",
                            host="localhost",
                            password="kaced14",
                            port="5432") 

    # Create a cursor. The cursor allows you to execute database queries. 
    cur = conn.cursor()
    
    # Afficher la version de PostgreSQL 
    cur.execute("SELECT version();")
    version = cur.fetchone()
    print("Version : ", version,"\n")
    
    # Create a table. Initialise the table name, the column names and data type. 
    cur.execute("""CREATE TABLE NEW (
                        id          serial PRIMARY KEY ,
                        fruit       INT,
                        color       INT,
                        price       REAL )""")

    
    iris = datasets.load_iris()
    
    X= iris.data[:,:]
    Y= iris.target
    
    c=0
    for i in X:
        print(i)
        c=c+1
        
    print(c)
    
    cur.execute("INSERT INTO NEW (fruit, color,price) VALUES (%s, %s, %s);", (160, 150,120.3))
    print("Inserted 1 rows of data")
    
    
    #fermeture de la connexion à la base de données
    conn.commit()
    conn.close()

    print("La connexion PostgreSQL est fermée")
except (Exception, psycopg2.Error) as error :
    print ("Erreur lors de la connexion à PostgreSQL", error)
# Out:
# Version :  ('PostgreSQL 10.14, compiled by Visual C++ build 1800, 32-bit',)
#
# [5.1 3.5 1.4 0.2]
# [4.9 3.  1.4 0.2]
# [4.7 3.2 1.3 0.2]
# [4.6 3.1 1.5 0.2]
# [5.  3.6 1.4 0.2]
# [5.4 3.9 1.7 0.4]
# [4.6 3.4 1.4 0.3]
# [5.  3.4 1.5 0.2]
# [4.4 2.9 1.4 0.2]
# [4.9 3.1 1.5 0.1]
# [5.4 3.7 1.5 0.2]
# [4.8 3.4 1.6 0.2]
# [4.8 3.  1.4 0.1]
# [4.3 3.  1.1 0.1]
# [5.8 4.  1.2 0.2]
# [5.7 4.4 1.5 0.4]
# [5.4 3.9 1.3 0.4]
# [5.1 3.5 1.4 0.3]
# [5.7 3.8 1.7 0.3]
# [5.1 3.8 1.5 0.3]
# [5.4 3.4 1.7 0.2]
# [5.1 3.7 1.5 0.4]
# [4.6 3.6 1.  0.2]
# [5.1 3.3 1.7 0.5]
# [4.8 3.4 1.9 0.2]
# [5.  3.  1.6 0.2]
# [5.  3.4 1.6 0.4]
# [5.2 3.5 1.5 0.2]
# [5.2 3.4 1.4 0.2]
# [4.7 3.2 1.6 0.2]
# [4.8 3.1 1.6 0.2]
# [5.4 3.4 1.5 0.4]
# [5.2 4.1 1.5 0.1]
# [5.5 4.2 1.4 0.2]
# [4.9 3.1 1.5 0.2]
# [5.  3.2 1.2 0.2]
# [5.5 3.5 1.3 0.2]
# [4.9 3.6 1.4 0.1]
# [4.4 3.  1.3 0.2]
# [5.1 3.4 1.5 0.2]
# [5.  3.5 1.3 0.3]
# [4.5 2.3 1.3 0.3]
# [4.4 3.2 1.3 0.2]
# [5.  3.5 1.6 0.6]
# [5.1 3.8 1.9 0.4]
# [4.8 3.  1.4 0.3]
# [5.1 3.8 1.6 0.2]
# [4.6 3.2 1.4 0.2]
# [5.3 3.7 1.5 0.2]
# [5.  3.3 1.4 0.2]
# [7.  3.2 4.7 1.4]
# [6.4 3.2 4.5 1.5]
# [6.9 3.1 4.9 1.5]
# [5.5 2.3 4.  1.3]
# [6.5 2.8 4.6 1.5]
# [5.7 2.8 4.5 1.3]
# [6.3 3.3 4.7 1.6]
# [4.9 2.4 3.3 1. ]
# [6.6 2.9 4.6 1.3]
# [5.2 2.7 3.9 1.4]
# [5.  2.  3.5 1. ]
# [5.9 3.  4.2 1.5]
# [6.  2.2 4.  1. ]
# [6.1 2.9 4.7 1.4]
# [5.6 2.9 3.6 1.3]
# [6.7 3.1 4.4 1.4]
# [5.6 3.  4.5 1.5]
# [5.8 2.7 4.1 1. ]
# [6.2 2.2 4.5 1.5]
# [5.6 2.5 3.9 1.1]
# [5.9 3.2 4.8 1.8]
# [6.1 2.8 4.  1.3]
# [6.3 2.5 4.9 1.5]
# [6.1 2.8 4.7 1.2]
# [6.4 2.9 4.3 1.3]
# [6.6 3.  4.4 1.4]
# [6.8 2.8 4.8 1.4]
# [6.7 3.  5.  1.7]
# [6.  2.9 4.5 1.5]
# [5.7 2.6 3.5 1. ]
# [5.5 2.4 3.8 1.1]
# [5.5 2.4 3.7 1. ]
# [5.8 2.7 3.9 1.2]
# [6.  2.7 5.1 1.6]
# [5.4 3.  4.5 1.5]
# [6.  3.4 4.5 1.6]
# [6.7 3.1 4.7 1.5]
# [6.3 2.3 4.4 1.3]
# [5.6 3.  4.1 1.3]
# [5.5 2.5 4.  1.3]
# [5.5 2.6 4.4 1.2]
# [6.1 3.  4.6 1.4]
# [5.8 2.6 4.  1.2]
# [5.  2.3 3.3 1. ]
# [5.6 2.7 4.2 1.3]
# [5.7 3.  4.2 1.2]
# [5.7 2.9 4.2 1.3]
# [6.2 2.9 4.3 1.3]
# [5.1 2.5 3.  1.1]
# [5.7 2.8 4.1 1.3]
# [6.3 3.3 6.  2.5]
# [5.8 2.7 5.1 1.9]
# [7.1 3.  5.9 2.1]
# [6.3 2.9 5.6 1.8]
# [6.5 3.  5.8 2.2]
# [7.6 3.  6.6 2.1]
# [4.9 2.5 4.5 1.7]
# [7.3 2.9 6.3 1.8]
# [6.7 2.5 5.8 1.8]
# [7.2 3.6 6.1 2.5]
# [6.5 3.2 5.1 2. ]
# [6.4 2.7 5.3 1.9]
# [6.8 3.  5.5 2.1]
# [5.7 2.5 5.  2. ]
# [5.8 2.8 5.1 2.4]
# [6.4 3.2 5.3 2.3]
# [6.5 3.  5.5 1.8]
# [7.7 3.8 6.7 2.2]
# [7.7 2.6 6.9 2.3]
# [6.  2.2 5.  1.5]
# [6.9 3.2 5.7 2.3]
# [5.6 2.8 4.9 2. ]
# [7.7 2.8 6.7 2. ]
# [6.3 2.7 4.9 1.8]
# [6.7 3.3 5.7 2.1]
# [7.2 3.2 6.  1.8]
# [6.2 2.8 4.8 1.8]
# [6.1 3.  4.9 1.8]
# [6.4 2.8 5.6 2.1]
# [7.2 3.  5.8 1.6]
# [7.4 2.8 6.1 1.9]
# [7.9 3.8 6.4 2. ]
# [6.4 2.8 5.6 2.2]
# [6.3 2.8 5.1 1.5]
# [6.1 2.6 5.6 1.4]
# [7.7 3.  6.1 2.3]
# [6.3 3.4 5.6 2.4]
# [6.4 3.1 5.5 1.8]
# [6.  3.  4.8 1.8]
# [6.9 3.1 5.4 2.1]
# [6.7 3.1 5.6 2.4]
# [6.9 3.1 5.1 2.3]
# [5.8 2.7 5.1 1.9]
# [6.8 3.2 5.9 2.3]
# [6.7 3.3 5.7 2.5]
# [6.7 3.  5.2 2.3]
# [6.3 2.5 5.  1.9]
# [6.5 3.  5.2 2. ]
# [6.2 3.4 5.4 2.3]
# [5.9 3.  5.1 1.8]
# 150
# Inserted 1 rows of data
# La connexion PostgreSQL est fermée

# %%
import psycopg2
from sklearn import datasets
try:

    # Establish a connection to the database.
    # Replace parameter values with database credentials.
    conn = psycopg2.connect(database="postgres", 
                            user="postgres",
                            host="localhost",
                            password="kaced14",
                            port="5432") 

    # Create a cursor. The cursor allows you to execute database queries. 
    cur = conn.cursor()
    
    # Afficher la version de PostgreSQL 
    cur.execute("SELECT version();")
    version = cur.fetchone()
    print("Version : ", version,"\n")
    
    # Drop previous table of same name if one exists
    cur.execute("DROP TABLE IF EXISTS Iris;")
    print("Finished dropping table (if existed)")
    
    # Create a table. Initialise the table name, the column names and data type. 
    cur.execute("""CREATE TABLE Iris (
                        
                        sepal_length       REAL,
                        sepal_width        REAL,
                        petal_length       REAL,
                        petal_width        REAL )""")

    
    iris = datasets.load_iris()
    
    X= iris.data[:,:]
    Y= iris.target
    
    c=0
    for i in X:
        print(i)
        c=c+1
        
    print(c)
    
    cur.execute("INSERT INTO Iris (sepal_length, sepal_width,petal_length,petal_width) VALUES (%s, %s, %s, %s);", (5.1, 3.5,1.4,0.2))
    print("Inserted 1 row of data")
    
    
    #fermeture de la connexion à la base de données
    conn.commit()
    conn.close()

    print("La connexion PostgreSQL est fermée")
except (Exception, psycopg2.Error) as error :
    print ("Erreur lors de la connexion à PostgreSQL", error)
# Out:
# Version :  ('PostgreSQL 10.14, compiled by Visual C++ build 1800, 32-bit',)
#
# Finished dropping table (if existed)
# [5.1 3.5 1.4 0.2]
# [4.9 3.  1.4 0.2]
# [4.7 3.2 1.3 0.2]
# [4.6 3.1 1.5 0.2]
# [5.  3.6 1.4 0.2]
# [5.4 3.9 1.7 0.4]
# [4.6 3.4 1.4 0.3]
# [5.  3.4 1.5 0.2]
# [4.4 2.9 1.4 0.2]
# [4.9 3.1 1.5 0.1]
# [5.4 3.7 1.5 0.2]
# [4.8 3.4 1.6 0.2]
# [4.8 3.  1.4 0.1]
# [4.3 3.  1.1 0.1]
# [5.8 4.  1.2 0.2]
# [5.7 4.4 1.5 0.4]
# [5.4 3.9 1.3 0.4]
# [5.1 3.5 1.4 0.3]
# [5.7 3.8 1.7 0.3]
# [5.1 3.8 1.5 0.3]
# [5.4 3.4 1.7 0.2]
# [5.1 3.7 1.5 0.4]
# [4.6 3.6 1.  0.2]
# [5.1 3.3 1.7 0.5]
# [4.8 3.4 1.9 0.2]
# [5.  3.  1.6 0.2]
# [5.  3.4 1.6 0.4]
# [5.2 3.5 1.5 0.2]
# [5.2 3.4 1.4 0.2]
# [4.7 3.2 1.6 0.2]
# [4.8 3.1 1.6 0.2]
# [5.4 3.4 1.5 0.4]
# [5.2 4.1 1.5 0.1]
# [5.5 4.2 1.4 0.2]
# [4.9 3.1 1.5 0.2]
# [5.  3.2 1.2 0.2]
# [5.5 3.5 1.3 0.2]
# [4.9 3.6 1.4 0.1]
# [4.4 3.  1.3 0.2]
# [5.1 3.4 1.5 0.2]
# [5.  3.5 1.3 0.3]
# [4.5 2.3 1.3 0.3]
# [4.4 3.2 1.3 0.2]
# [5.  3.5 1.6 0.6]
# [5.1 3.8 1.9 0.4]
# [4.8 3.  1.4 0.3]
# [5.1 3.8 1.6 0.2]
# [4.6 3.2 1.4 0.2]
# [5.3 3.7 1.5 0.2]
# [5.  3.3 1.4 0.2]
# [7.  3.2 4.7 1.4]
# [6.4 3.2 4.5 1.5]
# [6.9 3.1 4.9 1.5]
# [5.5 2.3 4.  1.3]
# [6.5 2.8 4.6 1.5]
# [5.7 2.8 4.5 1.3]
# [6.3 3.3 4.7 1.6]
# [4.9 2.4 3.3 1. ]
# [6.6 2.9 4.6 1.3]
# [5.2 2.7 3.9 1.4]
# [5.  2.  3.5 1. ]
# [5.9 3.  4.2 1.5]
# [6.  2.2 4.  1. ]
# [6.1 2.9 4.7 1.4]
# [5.6 2.9 3.6 1.3]
# [6.7 3.1 4.4 1.4]
# [5.6 3.  4.5 1.5]
# [5.8 2.7 4.1 1. ]
# [6.2 2.2 4.5 1.5]
# [5.6 2.5 3.9 1.1]
# [5.9 3.2 4.8 1.8]
# [6.1 2.8 4.  1.3]
# [6.3 2.5 4.9 1.5]
# [6.1 2.8 4.7 1.2]
# [6.4 2.9 4.3 1.3]
# [6.6 3.  4.4 1.4]
# [6.8 2.8 4.8 1.4]
# [6.7 3.  5.  1.7]
# [6.  2.9 4.5 1.5]
# [5.7 2.6 3.5 1. ]
# [5.5 2.4 3.8 1.1]
# [5.5 2.4 3.7 1. ]
# [5.8 2.7 3.9 1.2]
# [6.  2.7 5.1 1.6]
# [5.4 3.  4.5 1.5]
# [6.  3.4 4.5 1.6]
# [6.7 3.1 4.7 1.5]
# [6.3 2.3 4.4 1.3]
# [5.6 3.  4.1 1.3]
# [5.5 2.5 4.  1.3]
# [5.5 2.6 4.4 1.2]
# [6.1 3.  4.6 1.4]
# [5.8 2.6 4.  1.2]
# [5.  2.3 3.3 1. ]
# [5.6 2.7 4.2 1.3]
# [5.7 3.  4.2 1.2]
# [5.7 2.9 4.2 1.3]
# [6.2 2.9 4.3 1.3]
# [5.1 2.5 3.  1.1]
# [5.7 2.8 4.1 1.3]
# [6.3 3.3 6.  2.5]
# [5.8 2.7 5.1 1.9]
# [7.1 3.  5.9 2.1]
# [6.3 2.9 5.6 1.8]
# [6.5 3.  5.8 2.2]
# [7.6 3.  6.6 2.1]
# [4.9 2.5 4.5 1.7]
# [7.3 2.9 6.3 1.8]
# [6.7 2.5 5.8 1.8]
# [7.2 3.6 6.1 2.5]
# [6.5 3.2 5.1 2. ]
# [6.4 2.7 5.3 1.9]
# [6.8 3.  5.5 2.1]
# [5.7 2.5 5.  2. ]
# [5.8 2.8 5.1 2.4]
# [6.4 3.2 5.3 2.3]
# [6.5 3.  5.5 1.8]
# [7.7 3.8 6.7 2.2]
# [7.7 2.6 6.9 2.3]
# [6.  2.2 5.  1.5]
# [6.9 3.2 5.7 2.3]
# [5.6 2.8 4.9 2. ]
# [7.7 2.8 6.7 2. ]
# [6.3 2.7 4.9 1.8]
# [6.7 3.3 5.7 2.1]
# [7.2 3.2 6.  1.8]
# [6.2 2.8 4.8 1.8]
# [6.1 3.  4.9 1.8]
# [6.4 2.8 5.6 2.1]
# [7.2 3.  5.8 1.6]
# [7.4 2.8 6.1 1.9]
# [7.9 3.8 6.4 2. ]
# [6.4 2.8 5.6 2.2]
# [6.3 2.8 5.1 1.5]
# [6.1 2.6 5.6 1.4]
# [7.7 3.  6.1 2.3]
# [6.3 3.4 5.6 2.4]
# [6.4 3.1 5.5 1.8]
# [6.  3.  4.8 1.8]
# [6.9 3.1 5.4 2.1]
# [6.7 3.1 5.6 2.4]
# [6.9 3.1 5.1 2.3]
# [5.8 2.7 5.1 1.9]
# [6.8 3.2 5.9 2.3]
# [6.7 3.3 5.7 2.5]
# [6.7 3.  5.2 2.3]
# [6.3 2.5 5.  1.9]
# [6.5 3.  5.2 2. ]
# [6.2 3.4 5.4 2.3]
# [5.9 3.  5.1 1.8]
# 150
# Inserted 1 row of data
# La connexion PostgreSQL est fermée

# %%
import psycopg2
import pandas as pd
# URL of dataset (EU industry production data)
dataset_tsv_url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'

# Read in dataset: From compressed TSV file directly to pandas dataframe
df = pd.read_csv(dataset_tsv_url, sep='\t|,', index_col=[0,1,2,3,4], engine='python',names = ["sepal_length","sepal_width","petal_length","petal_width","classe"])
print(df)
rows_num = df['classe'].count()
print(rows_num)
import sqlalchemy  # Package for accessing SQL databases via Python

# Connect to database (Note: The package psychopg2 is required for Postgres to work with SQLAlchemy)
engine = sqlalchemy.create_engine("postgresql://postgres:kaced14@localhost/Iris")
con = engine.connect()
   
# Verify that there are no existing tables
print(engine.table_names())

table_name = 'tab_iris'
df.to_sql(table_name, con)

con.close()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          classe
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]
# 150
# ['tab_iris']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-b6b2f1124db7> in <module>
#      19
#      20 table_name = 'tab_iris'
# ---> 21 df.to_sql(table_name, con)
#      22
#      23 con.close()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2710             chunksize=chunksize,
#    2711             dtype=dtype,
# -> 2712             method=method,
#    2713         )
#    2714
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     516         chunksize=chunksize,
#     517         dtype=dtype,
# --> 518         method=method,
#     519     )
#     520
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1317             dtype=dtype,
#    1318         )
# -> 1319         table.create()
#    1320         table.insert(chunksize, method=method)
#    1321         if not name.isdigit() and not name.islower():
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in create(self)
#     642             if self.if_exists == "fail":
#     643                 raise ValueError(
# --> 644                     "Table '{name}' already exists.".format(name=self.name)
#     645                 )
#     646             elif self.if_exists == "replace":
#
# ValueError: Table 'tab_iris' already exists.

# %%
import psycopg2
import pandas as pd
# URL of dataset (EU industry production data)
dataset_tsv_url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'

# Read in dataset: From compressed TSV file directly to pandas dataframe
df = pd.read_csv(dataset_tsv_url, sep='\t|,', engine='python',names = ["sepal_length","sepal_width","petal_length","petal_width","classe"])
print(df)

rows_num = df['classe'].count()
print(rows_num)

import sqlalchemy  # Package for accessing SQL databases via Python

# Connect to database (Note: The package psychopg2 is required for Postgres to work with SQLAlchemy)
engine = sqlalchemy.create_engine("postgresql://postgres:kaced14@localhost/Iris")
con = engine.connect()
   
# Verify that there are no existing tables
print(engine.table_names())

table_name = 'tab_iris'
df.to_sql(table_name, con)

con.close()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          classe
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]
# 150
# []
